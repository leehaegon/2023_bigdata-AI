# %% [markdown]
# <a href="https://colab.research.google.com/github/leehaegon/bigdata/blob/main/bigdata230522.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url = 'https://api.odcloud.kr/api/15004246/v1/uddi:6c4f2ce3-5a37-4c02-969d-9651e9b90188_201712151547?page=1&perPage=10&serviceKey=UrO0JlwgX5Ei40xoe8XR48bOz7GwJFRqDhq7wn%2BqLvxvnUlBZbjyQOoWAsGAvRsSt%2Bw607%2BQpOEtFj5FRgHHBg%3D%3D'

# %%
#url 불러오기
import requests
response = requests.get(url)

# %%
#데이터 값 출력
contents = response.text
print(contents)
# Out:
# {"currentCount":10,"data":[{"공시지가":"1080000","도로교통":"세로(가)","면적":"151.1","본번지":"903","부번지":"10","소재지":" 만수동 903-10","시군구":"28200","시군구명":"남동구","시도명":"인천광역시","용도지역1":"제2종일반주거지역","용도지역2":"","읍면동리":"10300","이용상황":"단독주택","일련번호":"665","주위환경":"정비된 주택지대","지리적위치1":"만수북초등학교","지리적위치2":"남서측 인근","지목":"대","지번구분":"1","지세명":"평지","형상명":"정방형"},{"공시지가":"1230000","도로교통":"소로한면","면적":"149.8","본번지":"903","부번지":"17","소재지":" 만수동 903-17","시군구":"28200","시군구명":"남동구","시도명":"인천광역시","용도지역1":"제2종일반주거지역","용도지역2":"","읍면동리":"10300","이용상황":"주상용","일련번호":"666","주위환경":"주택 및 상가혼용지대","지리적위치1":"만수북초등학교","지리적위치2":"남서측 인근","지목":"대","지번구분":"1","지세명":"평지","형상명":"정방형"},{"공시지가":"923000","도로교통":"중로한면","면적":"166.9","본번지":"574","부번지":"27","소재지":" 일산동 574-27","시군구":"31170","시군구명":"동구","시도명":"울산광역시","용도지역1":"일반상업지역","용도지역2":"","읍면동리":"10300","이용상황":"단독주택","일련번호":"329","주위환경":"정비된 주택지대","지리적위치1":"일산동사무소","지리적위치2":"북측 인근","지목":"대","지번구분":"1","지세명":"완경사지","형상명":"자루형"},{"공시지가":"914000","도로교통":"세로(가)","면적":"160.4","본번지":"575","부번지":"41","소
# ...

# %%
#문자열을 json으로 변경
import json
json_ob = json.loads(contents)
print(json_ob)
print(json_ob.keys())
print(json_ob.values())
# Out:
# {'currentCount': 10, 'data': [{'공시지가': '1080000', '도로교통': '세로(가)', '면적': '151.1', '본번지': '903', '부번지': '10', '소재지': ' 만수동 903-10', '시군구': '28200', '시군구명': '남동구', '시도명': '인천광역시', '용도지역1': '제2종일반주거지역', '용도지역2': '', '읍면동리': '10300', '이용상황': '단독주택', '일련번호': '665', '주위환경': '정비된 주택지대', '지리적위치1': '만수북초등학교', '지리적위치2': '남서측 인근', '지목': '대', '지번구분': '1', '지세명': '평지', '형상명': '정방형'}, {'공시지가': '1230000', '도로교통': '소로한면', '면적': '149.8', '본번지': '903', '부번지': '17', '소재지': ' 만수동 903-17', '시군구': '28200', '시군구명': '남동구', '시도명': '인천광역시', '용도지역1': '제2종일반주거지역', '용도지역2': '', '읍면동리': '10300', '이용상황': '주상용', '일련번호': '666', '주위환경': '주택 및 상가혼용지대', '지리적위치1': '만수북초등학교', '지리적위치2': '남서측 인근', '지목': '대', '지번구분': '1', '지세명': '평지', '형상명': '정방형'}, {'공시지가': '923000', '도로교통': '중로한면', '면적': '166.9', '본번지': '574', '부번지': '27', '소재지': ' 일산동 574-27', '시군구': '31170', '시군구명': '동구', '시도명': '울산광역시', '용도지역1': '일반상업지역', '용도지역2': '', '읍면동리': '10300', '이용상황': '단독주택', '일련번호': '329', '주위환경': '정비된 주택지대', '지리적위치1': '일산동사무소', '지리적위치2': '북측 
# ...

# %%
# key를 기준으로 필요한 내용 추출
count = json_ob['currentCount']
print(count)
# key를 기준으로 필요한 내용 추출
data = json_ob['data']
print(data)
# Out:
# 10
# ...

# %%
# key를 기준으로 필요한 내용 추출후 데이터프레임으로 변경
import pandas as pd
data_df = pd.DataFrame(json_ob['data'])
print(data_df)
data_df.to_csv('국토교통부_표준지공시지가_0_9.csv')
# Out:
#       공시지가   도로교통      면적  본번지 부번지          소재지    시군구 시군구명    시도명      용도지역1  \
# 0  1080000  세로(가)   151.1  903  10   만수동 903-10  28200  남동구  인천광역시  제2종일반주거지역
# 1  1230000   소로한면   149.8  903  17   만수동 903-17  28200  남동구  인천광역시  제2종일반주거지역
# 2   923000   중로한면   166.9  574  27   일산동 574-27  31170   동구  울산광역시     일반상업지역
# 3   914000  세로(가)   160.4  575  41   일산동 575-41  31170   동구  울산광역시  제2종일반주거지역
# 4   886000  세로(가)   231.9  578  38   일산동 578-38  31170   동구  울산광역시  제2종일반주거지역
# 5  2630000   광대소각  1037.7  579   8    일산동 579-8  31170   동구  울산광역시     일반상업지역
# 6  1660000   소로각지   153.5  579  16   일산동 579-16  31170   동구  울산광역시     일반상업지역
# 7  1140000  세로(가)   135.6  579  50   일산동 579-50  31170   동구  울산광역시     일반상업지역
# 8  2460000   중로한면   303.4  581  17   일산동 581-17  31170   동구  울산광역시     일반상업지역
# 9   602000   소로각지    1498  939   4    일산동 939-4  31170   동구  울산광역시     자연녹지지역
#
#    ...   읍면동리  이용상황 일련번호         주위환경   지리적위치1   지리적위치2 지목 지번구분   지세명    형상명
# ...

# %%
#라이브러리 import
import requests
import json

# %%
# url 입력
url ='http://apis.data.go.kr/1480523/MetalMeasuringResultService'
key ='UrO0JlwgX5Ei40xoe8XR48bOz7GwJFRqDhq7wn%2BqLvxvnUlBZbjyQOoWAsGAvRsSt%2Bw607%2BQpOEtFj5FRgHHBg%3D%3D'
page = '&pageNo=1&numOfRows=10&resultType=XML&date='
date = '20171231'
etc = '&stationcode=1&itemcode=90303&timecode=RH02'

# %%
# url 불러오기
response = requests.get(url+key+page+date+etc)

# %%
#데이터 값 출력
contents = response.text
print(contents)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
#     <soapenv:Body>
#         <soapenv:Fault>
#             <faultcode>soapenv:Server</faultcode>
#             <faultstring>Policy Falsified</faultstring>
#             <faultactor>http://apis.data.go.kr/1480523/MetalMeasuringResultServiceUrO0JlwgX5Ei40xoe8XR48bOz7GwJFRqDhq7wn%2BqLvxvnUlBZbjyQOoWAsGAvRsSt%2Bw607%2BQpOEtFj5FRgHHBg%3D%3D&amp;pageNo=1&amp;numOfRows=10&amp;resultType=XML&amp;date=20171231&amp;stationcode=1&amp;itemcode=90303&amp;timecode=RH02</faultactor>
#             <detail>
#                 <l7:policyResult
#                     status="Service Not Found.  The request may have been sent to an invalid URL, or intended for an unsupported operation." xmlns:l7="http://www.layer7tech.com/ws/policy/fault"/>
#             </detail>
#         </soapenv:Fault>
#     </soapenv:Body>
# </soapenv:Envelope>

# %%
import xml.etree.ElementTree as et
import bs4
from lxml import html
xml_obj = bs4.BeautifulSoup(contents,'lxml-xml')
rows = xml_obj.findAll('item')
print(rows)
# Out:
# []

# %%
row_list = []
name_list = []
value_list = []
for i in range(len(rows)):
  cols = rows[i].find_all()
  for j in range(len(cols)):
    if i == 0:
      name_list.append(cols[j].name)
    value_list.append(cols[j].text)
  row_list.append(value_list)
  value_list = []
df = pd.DataFrame(row_list, columns = name_list)
print(df)
df.to_csv('환경부 국립환경과학원_미세먼지(금속성분) 실시간 정보'+ date + '.csv')
# Out:
# Empty DataFrame
# Columns: []
# Index: []
